# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = {
 'car' : ['mercedes', 'bmw', 'volvo', 'tata', 'huyandai', 'honda'],
 'cost' : ['60k', '30k', '20k', '40k', '60k', '90k'],
 'year' : [2018, 2019, 2020, 2021, 2022, 2023]
}

# %%
dataset.keys()
# Out:
# dict_keys(['car', 'cost', 'year'])

# %%
dataset.values()
# Out:
# dict_values([['mercedes', 'bmw', 'volvo', 'tata', 'huyandai', 'honda'], ['60k', '30k', '20k', '40k', '60k', '90k'], [2018, 2019, 2020, 2021, 2022, 2023]])

# %%
cars = pd.DataFrame(dataset, columns=dataset.keys())

# %%
cars
# Out:
#         car cost  year
# 0  mercedes  60k  2018
# 1       bmw  30k  2019
# 2     volvo  20k  2020
# 3      tata  40k  2021
# 4  huyandai  60k  2022
# 5     honda  90k  2023

# %%
cars.columns
# Out:
# Index(['car', 'cost', 'year'], dtype='object')

# %%
cars.head()
# Out:
#         car cost  year
# 0  mercedes  60k  2018
# 1       bmw  30k  2019
# 2     volvo  20k  2020
# 3      tata  40k  2021
# 4  huyandai  60k  2022

# %%
cars.tail()
# Out:
#         car cost  year
# 1       bmw  30k  2019
# 2     volvo  20k  2020
# 3      tata  40k  2021
# 4  huyandai  60k  2022
# 5     honda  90k  2023

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cars['car'])
# Out:
# pandas.core.series.Series

# %%
cars.head(2)
# Out:
#         car cost  year
# 0  mercedes  60k  2018
# 1       bmw  30k  2019

# %%
cars.shape
# Out:
# (6, 3)

# %%
cars[['car', 'year']][2:5]
# Out:
#         car  year
# 2     volvo  2020
# 3      tata  2021
# 4  huyandai  2022

# %%
cars[cars.year == 2020]
# Out:
#      car cost  year
# 2  volvo  20k  2020

# %%
cars[(cars.year == 2020) & (cars.cost == '20k')]
# Out:
#      car cost  year
# 2  volvo  20k  2020

# %%
cars[~(cars.year == 2020)]
# Out:
#         car cost  year
# 0  mercedes  60k  2018
# 1       bmw  30k  2019
# 3      tata  40k  2021
# 4  huyandai  60k  2022
# 5     honda  90k  2023

# %%
cars[cars.year != 2020]
# Out:
#         car cost  year
# 0  mercedes  60k  2018
# 1       bmw  30k  2019
# 3      tata  40k  2021
# 4  huyandai  60k  2022
# 5     honda  90k  2023

# %%
cars[~cars.isin(cars.loc[cars[cars.year == 2020].index])]
# Out:
#         car cost    year
# 0  mercedes  60k  2018.0
# 1       bmw  30k  2019.0
# 2       NaN  NaN     NaN
# 3      tata  40k  2021.0
# 4  huyandai  60k  2022.0
# 5     honda  90k  2023.0

# %%
cars[(cars.year == 2020)].index
# Out:
# Int64Index([2], dtype='int64')

# %%
dataset = pd.read_excel('/Users/rishavdas/Downloads/Data/HR_Employee_Attrition-1.xlsx')

# %%
dataset.head()
# Out:
#    EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0               1       Yes   41      Travel_Rarely       1102
# 1               2        No   49  Travel_Frequently        279
# 2               3       Yes   37      Travel_Rarely       1373
# 3               4        No   33  Travel_Frequently       1392
# 4               5        No   27      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                         1            80
# ...

# %%
dataset.columns
# Out:
# Index(['EmployeeNumber', 'Attrition', 'Age', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (2940, 35)

# %%
dataset[dataset['Age'] > 40]
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0                  1       Yes   41      Travel_Rarely       1102
# 1                  2        No   49  Travel_Frequently        279
# 6                  7        No   59      Travel_Rarely       1324
# 18                19        No   53      Travel_Rarely       1219
# 25                26        No   53      Travel_Rarely       1282
# ...              ...       ...  ...                ...        ...
# 2918            2919        No   41      Travel_Rarely        930
# 2922            2923       Yes   50  Travel_Frequently        878
# 2924            2925        No   45      Travel_Rarely        374
# 2931            2932       Yes   50      Travel_Rarely        410
# 2938            2939        No   49  Travel_Frequently       1023
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
dataset[(dataset.Age > 40) & (dataset.Department == 'Sales')][['EmployeeNumber', 'Age', 'Department']]
# Out:
#       EmployeeNumber  Age Department
# 0                  1   41      Sales
# 18                19   53      Sales
# 27                28   42      Sales
# 29                30   46      Sales
# 36                37   50      Sales
# ...              ...  ...        ...
# 2918            2919   41      Sales
# 2922            2923   50      Sales
# 2924            2925   45      Sales
# 2931            2932   50      Sales
# 2938            2939   49      Sales
#
# [266 rows x 3 columns]

# %%
dataset[(dataset.Age > 40) & (dataset.Department == 'Sales')]
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2935    False
# 2936    False
# 2937    False
# 2938     True
# 2939    False
# Name: EmployeeNumber, Length: 2940, dtype: bool
